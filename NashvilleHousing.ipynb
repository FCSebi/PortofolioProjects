# %%
# Import libraries

import pandas as pd
import numpy as np

import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (18,8)


#Import the csv file

df = pd.read_csv(r'C:\Users\Utilizator\Downloads\Nashville Housing Data for Data Cleaning.csv')


# see first 5 rows and all columns

df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress            SaleDate SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014    366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016    435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016    255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014    278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE
# ...

# %%
# Types of Data 

df.dtypes
# Out:
# UniqueID             int64
# ParcelID            object
# LandUse             object
# PropertyAddress     object
# SaleDate            object
# SalePrice           object
# LegalReference      object
# SoldAsVacant        object
# OwnerName           object
# OwnerAddress        object
# Acreage            float64
# TaxDistrict         object
# LandValue          float64
# BuildingValue      float64
# TotalValue         float64
# YearBuilt          float64
# Bedrooms           float64
# FullBath           float64
# HalfBath           float64
# dtype: object

# %%
# See if there is any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# UniqueID  - 0.0%
# ParcelID - 0.0%
# LandUse - 0.0%
# PropertyAddress - 0.0005134833649096093%
# SaleDate - 0.0%
# SalePrice - 0.0%
# LegalReference - 0.0%
# SoldAsVacant - 0.0%
# OwnerName - 0.0%
# OwnerAddress - 0.0%
# Acreage - 0.5393700090302247%
# TaxDistrict - 0.5393700090302247%
# LandValue - 0.5393700090302247%
# BuildingValue - 0.5393700090302247%
# TotalValue - 0.5393700090302247%
# YearBuilt - 0.572162119092728%
# Bedrooms - 0.5722683570302955%
# FullBath - 0.5701790109248013%
# HalfBath - 0.5724985392283585%
# New Date - 0.0%
# City - 0.0005134833649096093%
# New SalePrice - 0.0%
# New SalePrice2 - 0.9998760557395046%

# %%
#Search by condition

df.loc[df['SalePrice'] =="240000"]
# Out:
#        UniqueID           ParcelID            LandUse  \
# 0           2045   007 00 0 125.00      SINGLE FAMILY
# 153        44078   025 07 0 008.00      SINGLE FAMILY
# 622         2053  033 13 0A 023.00      SINGLE FAMILY
# 625        40669  033 13 0A 041.00      SINGLE FAMILY
# 1307       50592  041 06 0A 023.00      SINGLE FAMILY
# ...          ...               ...                ...
# 55061      16255  181 10 0A 133.00      SINGLE FAMILY
# 55416       2739  181 10 0E 096.00      SINGLE FAMILY
# 55838      39043  182 12 0A 058.00      SINGLE FAMILY
# 55863      54022  182 12 0A 131.00      SINGLE FAMILY
# 56247      48009  186 04 0B 057.00  RESIDENTIAL CONDO
#
#                           PropertyAddress            SaleDate SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 153      407  ROSEHILL DR, GOODLETTSVILLE    February 1, 2016    240000
# 622             848  CURTIS DR, NASHVILLE       April 1, 2013    240000
# ...

# %%
#

df.sort_values(['SaleDate','SalePrice']), ascending==[1,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 #
# ----> 3 df.sort_values(['SaleDate','SalePrice']), ascending==[1,0]
#
# NameError: name 'ascending' is not defined

# %%
df.head(5)
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress            SaleDate SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014    366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016    435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016    255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014    278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE
# ...

# %%
# To save .csv

df.to_csv('new filename', index=False)

# %%
# Check Null Values

df.isnull().any()
# Out:
# UniqueID           False
# ParcelID           False
# LandUse            False
# PropertyAddress     True
# SaleDate           False
# SalePrice          False
# LegalReference     False
# SoldAsVacant       False
# OwnerName           True
# OwnerAddress        True
# Acreage             True
# TaxDistrict         True
# LandValue           True
# BuildingValue       True
# TotalValue          True
# YearBuilt           True
# Bedrooms            True
# FullBath            True
# HalfBath            True
# dtype: bool

# %%
# Check Na for OwnerName

df[df['OwnerName'].isna()==1]
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 10         29467  007 14 0A 024.00            SINGLE FAMILY
# 11         10754  007 14 0A 027.00            SINGLE FAMILY
# 12         34751  007 14 0B 010.00        RESIDENTIAL CONDO
# 25         48716  011 15 0A 004.00            SINGLE FAMILY
# 108         2046  018 12 0A 004.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress           SaleDate SalePrice  \
# 10          2209  KAYLA DR, GOODLETTSVILLE     April 14, 2015    425000
# 11     109  BAILEY VIEW CT, GOODLETTSVILLE  December 12, 2013    585000
# ...

# %%
# Change NA to 0 for 	 OwnerName and OwnerAddress

df['OwnerName'] = df['OwnerName'].fillna(0)

df['OwnerAddress'] = df['OwnerAddress'].fillna(0)

# %%
df[df['OwnerName'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [UniqueID , ParcelID, LandUse, PropertyAddress, SaleDate, SalePrice, LegalReference, SoldAsVacant, OwnerName, OwnerAddress, Acreage, TaxDistrict, LandValue, BuildingValue, TotalValue, YearBuilt, Bedrooms, FullBath, HalfBath]
# Index: []

# %%
df.loc[df['SalePrice'] =="240000"]
# Out:
#        UniqueID           ParcelID            LandUse  \
# 0           2045   007 00 0 125.00      SINGLE FAMILY
# 153        44078   025 07 0 008.00      SINGLE FAMILY
# 622         2053  033 13 0A 023.00      SINGLE FAMILY
# 625        40669  033 13 0A 041.00      SINGLE FAMILY
# 1307       50592  041 06 0A 023.00      SINGLE FAMILY
# ...          ...               ...                ...
# 55061      16255  181 10 0A 133.00      SINGLE FAMILY
# 55416       2739  181 10 0E 096.00      SINGLE FAMILY
# 55838      39043  182 12 0A 058.00      SINGLE FAMILY
# 55863      54022  182 12 0A 131.00      SINGLE FAMILY
# 56247      48009  186 04 0B 057.00  RESIDENTIAL CONDO
#
#                           PropertyAddress            SaleDate SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 153      407  ROSEHILL DR, GOODLETTSVILLE    February 1, 2016    240000
# 622             848  CURTIS DR, NASHVILLE       April 1, 2013    240000
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 56472    False
# 56473    False
# 56474    False
# 56475    False
# 56476    False
# Length: 56477, dtype: bool

# %%
# Split 

df['New Date'] = df['LegalReference'].str.split(pat = '-').str[0]

# %%
df.head(5)
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress            SaleDate SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014    366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016    435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016    255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014    278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE
# ...

# %%
# City form Property address column

df['City'] = df['PropertyAddress'].str.split(pat = ',').str[1]

# %%
df.head(5)
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress            SaleDate SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014    366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016    435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016    255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014    278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE
# ...

# %%
#change data types

df.dtypes
# Out:
# UniqueID             int64
# ParcelID            object
# LandUse             object
# PropertyAddress     object
# SaleDate            object
# SalePrice           object
# LegalReference      object
# SoldAsVacant        object
# OwnerName           object
# OwnerAddress        object
# Acreage            float64
# TaxDistrict         object
# LandValue          float64
# BuildingValue      float64
# TotalValue         float64
# YearBuilt          float64
# Bedrooms           float64
# FullBath           float64
# HalfBath           float64
# New Date            object
# City                object
# dtype: object

# %%
df['SalePrice'].str.split(pat = '$').str[0]
# Out:
# 0        240000
# 1        366000
# 2        435000
# 3        255000
# 4        278000
#           ...
# 56472    157500
# 56473    145000
# 56474    234611
# 56475     93844
# 56476     93844
# Name: SalePrice, Length: 56477, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UniqueID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df.loc[df['UniqueID'] =="50606"]
#
# ...

# %%
df.loc[df['SalePrice'] =="$"]
# Out:
# Empty DataFrame
# Columns: [UniqueID , ParcelID, LandUse, PropertyAddress, SaleDate, SalePrice, LegalReference, SoldAsVacant, OwnerName, OwnerAddress, Acreage, TaxDistrict, LandValue, BuildingValue, TotalValue, YearBuilt, Bedrooms, FullBath, HalfBath, New Date, City]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.loc[df['LegalReference'] =="20160613-0059703"]
# Out:
#      UniqueID          ParcelID        LandUse  \
# 263      50606  026 06 0 011.00  ZERO LOT LINE
#
#                        PropertyAddress      SaleDate  SalePrice  \
# 263  122 HABERSHAM  CT, GOODLETTSVILLE  June 9, 2016  $120,000
#
#        LegalReference SoldAsVacant          OwnerName  \
# 263  20160613-0059703           No  DUVALL, LAUREN R.
#
#                               OwnerAddress  ...             TaxDistrict  \
# 263  122  HABERSHAM CT, GOODLETTSVILLE, TN  ...  CITY OF GOODLETTSVILLE
#
#     LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  \
# 263   15000.0        85000.0    100000.0     1986.0       3.0       2.0
#
#      HalfBath  New Date             City
# 263       0.0  20160613   GOODLETTSVILLE
#
# [1 rows x 21 columns]

# %%
df.loc[df['SalePrice'] =="1124900"]
# Out:
# Empty DataFrame
# Columns: [UniqueID , ParcelID, LandUse, PropertyAddress, SaleDate, SalePrice, LegalReference, SoldAsVacant, OwnerName, OwnerAddress, Acreage, TaxDistrict, LandValue, BuildingValue, TotalValue, YearBuilt, Bedrooms, FullBath, HalfBath, New Date, City]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.isnull().any()
# Out:
# UniqueID           False
# ParcelID           False
# LandUse            False
# PropertyAddress     True
# SaleDate           False
# SalePrice          False
# LegalReference     False
# SoldAsVacant       False
# OwnerName          False
# OwnerAddress       False
# Acreage             True
# TaxDistrict         True
# LandValue           True
# BuildingValue       True
# TotalValue          True
# YearBuilt           True
# Bedrooms            True
# FullBath            True
# HalfBath            True
# New Date           False
# City                True
# dtype: bool

# %%
df['SalePrice'] = df['SalePrice'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df['SalePrice'] = df['SalePrice'].astype('int')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
df.loc[df['LegalReference'] =="20161027-0113506"]
# Out:
#        UniqueID           ParcelID            LandUse  \
# 33741      55748  118 14 0C 002.00  RESIDENTIAL CONDO
#
#                      PropertyAddress          SaleDate    SalePrice  \
# 33741  3602 BCALDWELL  CT, NASHVILLE  October 24, 2016  $1,124,900
#
#          LegalReference SoldAsVacant OwnerName OwnerAddress  ...  TaxDistrict  \
# 33741  20161027-0113506           No         0            0  ...          NaN
#
#       LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  \
# 33741       NaN            NaN         NaN        NaN       NaN       NaN
#
#        HalfBath  New Date        City
# 33741       NaN  20161027   NASHVILLE
#
# [1 rows x 21 columns]

# %%
20151019-0106061
# Out:
# Empty DataFrame
# Columns: [UniqueID , ParcelID, LandUse, PropertyAddress, SaleDate, SalePrice, LegalReference, SoldAsVacant, OwnerName, OwnerAddress, Acreage, TaxDistrict, LandValue, BuildingValue, TotalValue, YearBuilt, Bedrooms, FullBath, HalfBath, New Date, City]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.loc[df['ParcelID'] =="118 14 0C 002.00"]
# Out:
#        UniqueID           ParcelID            LandUse  \
# 33741      55748  118 14 0C 002.00  RESIDENTIAL CONDO
#
#                      PropertyAddress          SaleDate    SalePrice  \
# 33741  3602 BCALDWELL  CT, NASHVILLE  October 24, 2016  $1,124,900
#
#          LegalReference SoldAsVacant OwnerName OwnerAddress  ...  TaxDistrict  \
# 33741  20161027-0113506           No         0            0  ...          NaN
#
#       LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  \
# 33741       NaN            NaN         NaN        NaN       NaN       NaN
#
#        HalfBath  New Date        City
# 33741       NaN  20161027   NASHVILLE
#
# [1 rows x 21 columns]

# %%
# Out:
# 1124900

# %%
df.loc[df['LegalReference'] =="20151019-0106061"]
# Out:
#       UniqueID          ParcelID        LandUse            PropertyAddress  \
# 8397      39539  071 15 0 337.00  SINGLE FAMILY  1219  N 2ND ST, NASHVILLE
#
#               SaleDate  SalePrice    LegalReference SoldAsVacant  \
# 8397  October 15, 2015  $362,500   20151019-0106061           No
#
#                        OwnerName                   OwnerAddress  ...  \
# 8397  WARD, SANDRA S. & DAVID S.  1219  N 2ND ST, NASHVILLE, TN  ...
#
#                   TaxDistrict LandValue  BuildingValue  TotalValue  YearBuilt  \
# 8397  URBAN SERVICES DISTRICT   27000.0       290700.0    330600.0     2015.0
#
#       Bedrooms  FullBath  HalfBath  New Date        City
# 8397       4.0       2.0       1.0  20151019   NASHVILLE
#
# [1 rows x 21 columns]

# %%
df.loc[df['SalePrice'] ==""]
# Out:
# Empty DataFrame
# Columns: [UniqueID , ParcelID, LandUse, PropertyAddress, SaleDate, SalePrice, LegalReference, SoldAsVacant, OwnerName, OwnerAddress, Acreage, TaxDistrict, LandValue, BuildingValue, TotalValue, YearBuilt, Bedrooms, FullBath, HalfBath, New Date, City]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['SalePrice'] = df['SalePrice'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 df['SalePrice'] = df['SalePrice'].astype('int')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
# Out:
#   Cell In[140], line 2
#     try:
#     ^
# IndentationError: unexpected indent

# %%
df['New SalePrice'] = df['SalePrice'].str.split(pat = '$').str[0]

# %%
df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress            SaleDate SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014    366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016    435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016    255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014    278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE
# ...

# %%
df.loc[df['LegalReference'] =="20151019-0106061"]
# Out:
#       UniqueID          ParcelID        LandUse            PropertyAddress  \
# 8397      39539  071 15 0 337.00  SINGLE FAMILY  1219  N 2ND ST, NASHVILLE
#
#               SaleDate  SalePrice    LegalReference SoldAsVacant  \
# 8397  October 15, 2015  $362,500   20151019-0106061           No
#
#                        OwnerName                   OwnerAddress  ...  \
# 8397  WARD, SANDRA S. & DAVID S.  1219  N 2ND ST, NASHVILLE, TN  ...
#
#       LandValue BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  \
# 8397    27000.0      290700.0    330600.0     2015.0       4.0       2.0
#
#       HalfBath  New Date        City New SalePrice
# 8397       1.0  20151019   NASHVILLE
#
# [1 rows x 22 columns]

# %%
df.loc[df['ParcelID'] =="118 14 0C 002.00"]
# Out:
#        UniqueID           ParcelID            LandUse  \
# 33741      55748  118 14 0C 002.00  RESIDENTIAL CONDO
#
#                      PropertyAddress          SaleDate    SalePrice  \
# 33741  3602 BCALDWELL  CT, NASHVILLE  October 24, 2016  $1,124,900
#
#          LegalReference SoldAsVacant OwnerName OwnerAddress  ...  LandValue  \
# 33741  20161027-0113506           No         0            0  ...        NaN
#
#       BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  HalfBath  \
# 33741           NaN         NaN        NaN       NaN       NaN       NaN
#
#        New Date        City New SalePrice
# 33741  20161027   NASHVILLE
#
# [1 rows x 22 columns]

# %%
df.dtypes
# Out:
# UniqueID             int64
# ParcelID            object
# LandUse             object
# PropertyAddress     object
# SaleDate            object
# SalePrice           object
# LegalReference      object
# SoldAsVacant        object
# OwnerName           object
# OwnerAddress        object
# Acreage            float64
# TaxDistrict         object
# LandValue          float64
# BuildingValue      float64
# TotalValue         float64
# YearBuilt          float64
# Bedrooms           float64
# FullBath           float64
# HalfBath           float64
# New Date            object
# City                object
# New SalePrice       object
# dtype: object

# %%
df['New SalePrice'] = df['New SalePrice'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 df['New SalePrice'] = df['New SalePrice'].astype('int')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# UniqueID  - 0.0%
# ParcelID - 0.0%
# LandUse - 0.0%
# PropertyAddress - 0.0005134833649096093%
# SaleDate - 0.0%
# SalePrice - 0.0%
# LegalReference - 0.0%
# SoldAsVacant - 0.0%
# OwnerName - 0.0%
# OwnerAddress - 0.0%
# Acreage - 0.5393700090302247%
# TaxDistrict - 0.5393700090302247%
# LandValue - 0.5393700090302247%
# BuildingValue - 0.5393700090302247%
# TotalValue - 0.5393700090302247%
# YearBuilt - 0.572162119092728%
# Bedrooms - 0.5722683570302955%
# FullBath - 0.5701790109248013%
# HalfBath - 0.5724985392283585%
# New Date - 0.0%
# City - 0.0005134833649096093%
# New SalePrice - 0.0%

# %%
df.loc[df['New SalePrice'] < "100"]
# Out:
#        UniqueID           ParcelID            LandUse  \
# 263        50606   026 06 0 011.00      ZERO LOT LINE
# 1508       39467   042 08 0 041.00      SINGLE FAMILY
# 8397       39539   071 15 0 337.00      SINGLE FAMILY
# 20447      17845  092 16 0D 118.00  RESIDENTIAL CONDO
# 33741      55748  118 14 0C 002.00  RESIDENTIAL CONDO
# 34003      23307   119 05 0 420.00      SINGLE FAMILY
# 47752      17651  161 06 0A 204.00  RESIDENTIAL CONDO
#
#                          PropertyAddress           SaleDate    SalePrice  \
# 263    122 HABERSHAM  CT, GOODLETTSVILLE       June 9, 2016    $120,000
# 1508          412  AMQUIWOOD CT, MADISON   October 19, 2015    $120,000
# 8397           1219  N 2ND ST, NASHVILLE   October 15, 2015    $362,500
# 20447          1803  BROADWAY, NASHVILLE      July 25, 2014    $195,000
# 33741      3602 BCALDWELL  CT, NASHVILLE   October 24, 2016  $1,124,900
# 34003           105  LUTIE ST, NASHVILLE  November 25, 2014    $195,000
# ...

# %%
df['New SalePrice2'] = df['SalePrice'].str.split(pat = '$').str[1]

# %%
df.loc[df['New SalePrice2'] < "10000"]
# Out:
#        UniqueID           ParcelID            LandUse  \
# 33741      55748  118 14 0C 002.00  RESIDENTIAL CONDO
#
#                      PropertyAddress          SaleDate    SalePrice  \
# 33741  3602 BCALDWELL  CT, NASHVILLE  October 24, 2016  $1,124,900
#
#          LegalReference SoldAsVacant OwnerName OwnerAddress  ...  \
# 33741  20161027-0113506           No         0            0  ...
#
#        BuildingValue TotalValue  YearBuilt  Bedrooms  FullBath  HalfBath  \
# 33741            NaN        NaN        NaN       NaN       NaN       NaN
#
#        New Date        City  New SalePrice New SalePrice2
# 33741  20161027   NASHVILLE                    1,124,900
#
# [1 rows x 23 columns]

# %%
print(df)
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress            SaleDate SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014    366000
# ...

# %%
def clean_currency(value):
    try:
        # Remove common currency symbols ($, €, etc.) and commas, then convert to float
        return float(str(value).replace('$', '').replace('€', '').replace(',', '').strip())
    except ValueError:
        return value

# %%
df.loc[df['New SalePrice'] < "100"]
# Out:
#        UniqueID           ParcelID            LandUse  \
# 263        50606   026 06 0 011.00      ZERO LOT LINE
# 1508       39467   042 08 0 041.00      SINGLE FAMILY
# 8397       39539   071 15 0 337.00      SINGLE FAMILY
# 20447      17845  092 16 0D 118.00  RESIDENTIAL CONDO
# 33741      55748  118 14 0C 002.00  RESIDENTIAL CONDO
# 34003      23307   119 05 0 420.00      SINGLE FAMILY
# 47752      17651  161 06 0A 204.00  RESIDENTIAL CONDO
#
#                          PropertyAddress           SaleDate    SalePrice  \
# 263    122 HABERSHAM  CT, GOODLETTSVILLE       June 9, 2016    $120,000
# 1508          412  AMQUIWOOD CT, MADISON   October 19, 2015    $120,000
# 8397           1219  N 2ND ST, NASHVILLE   October 15, 2015    $362,500
# 20447          1803  BROADWAY, NASHVILLE      July 25, 2014    $195,000
# 33741      3602 BCALDWELL  CT, NASHVILLE   October 24, 2016  $1,124,900
# 34003           105  LUTIE ST, NASHVILLE  November 25, 2014    $195,000
# ...

# %%
df.loc[df['New SalePrice'] < "100"]
# Out:
#        UniqueID           ParcelID            LandUse  \
# 263        50606   026 06 0 011.00      ZERO LOT LINE
# 1508       39467   042 08 0 041.00      SINGLE FAMILY
# 8397       39539   071 15 0 337.00      SINGLE FAMILY
# 20447      17845  092 16 0D 118.00  RESIDENTIAL CONDO
# 33741      55748  118 14 0C 002.00  RESIDENTIAL CONDO
# 34003      23307   119 05 0 420.00      SINGLE FAMILY
# 47752      17651  161 06 0A 204.00  RESIDENTIAL CONDO
#
#                          PropertyAddress           SaleDate    SalePrice  \
# 263    122 HABERSHAM  CT, GOODLETTSVILLE       June 9, 2016    $120,000
# 1508          412  AMQUIWOOD CT, MADISON   October 19, 2015    $120,000
# 8397           1219  N 2ND ST, NASHVILLE   October 15, 2015    $362,500
# 20447          1803  BROADWAY, NASHVILLE      July 25, 2014    $195,000
# 33741      3602 BCALDWELL  CT, NASHVILLE   October 24, 2016  $1,124,900
# 34003           105  LUTIE ST, NASHVILLE  November 25, 2014    $195,000
# ...

# %%
def clean_currency(value):
    try:
        # Remove common currency symbols ($, €, etc.) and commas, then convert to float
        return float(str(value).replace('$', '').replace(',', '').strip())
    except ValueError:
        return value
        df['SalePrice'] = df['SalePrice'].apply(clean_currency)
        print("\nCleaned Data:")

# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df['SalePrice'] = df['SalePrice'].apply(clean_currency)

# %%
print("\nCleaned Data:")
# Out:
# Cleaned Data:

# %%
print("\nCleaned Data:")
print(df)
# Out:
# Cleaned Data:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress            SaleDate  SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013   240000.0
# 1       1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014   366000.0
# ...

# %%
df.loc[df['LegalReference'] =="20151019-0106061"]
# Out:
#       UniqueID          ParcelID        LandUse            PropertyAddress  \
# 8397      39539  071 15 0 337.00  SINGLE FAMILY  1219  N 2ND ST, NASHVILLE
#
#               SaleDate  SalePrice    LegalReference SoldAsVacant  \
# 8397  October 15, 2015   362500.0  20151019-0106061           No
#
#                        OwnerName                   OwnerAddress  ...  \
# 8397  WARD, SANDRA S. & DAVID S.  1219  N 2ND ST, NASHVILLE, TN  ...
#
#       BuildingValue TotalValue  YearBuilt  Bedrooms  FullBath  HalfBath  \
# 8397       290700.0   330600.0     2015.0       4.0       2.0       1.0
#
#       New Date        City  New SalePrice New SalePrice2
# 8397  20151019   NASHVILLE                      362,500
#
# [1 rows x 23 columns]

# %%
df.dtypes
# Out:
# UniqueID             int64
# ParcelID            object
# LandUse             object
# PropertyAddress     object
# SaleDate            object
# SalePrice          float64
# LegalReference      object
# SoldAsVacant        object
# OwnerName           object
# OwnerAddress        object
# Acreage            float64
# TaxDistrict         object
# LandValue          float64
# BuildingValue      float64
# TotalValue         float64
# YearBuilt          float64
# Bedrooms           float64
# FullBath           float64
# HalfBath           float64
# New Date            object
# City                object
# New SalePrice       object
# New SalePrice2      object
# dtype: object

# %%
df.loc[df['New SalePrice'] < "100"]
# Out:
#        UniqueID           ParcelID            LandUse  \
# 263        50606   026 06 0 011.00      ZERO LOT LINE
# 1508       39467   042 08 0 041.00      SINGLE FAMILY
# 8397       39539   071 15 0 337.00      SINGLE FAMILY
# 20447      17845  092 16 0D 118.00  RESIDENTIAL CONDO
# 33741      55748  118 14 0C 002.00  RESIDENTIAL CONDO
# 34003      23307   119 05 0 420.00      SINGLE FAMILY
# 47752      17651  161 06 0A 204.00  RESIDENTIAL CONDO
#
#                          PropertyAddress           SaleDate  SalePrice  \
# 263    122 HABERSHAM  CT, GOODLETTSVILLE       June 9, 2016   120000.0
# 1508          412  AMQUIWOOD CT, MADISON   October 19, 2015   120000.0
# 8397           1219  N 2ND ST, NASHVILLE   October 15, 2015   362500.0
# 20447          1803  BROADWAY, NASHVILLE      July 25, 2014   195000.0
# 33741      3602 BCALDWELL  CT, NASHVILLE   October 24, 2016  1124900.0
# 34003           105  LUTIE ST, NASHVILLE  November 25, 2014   195000.0
# ...

# %%
df.loc[df['LegalReference'] =="20151019-0106061"]
# Out:
#       UniqueID          ParcelID        LandUse            PropertyAddress  \
# 8397      39539  071 15 0 337.00  SINGLE FAMILY  1219  N 2ND ST, NASHVILLE
#
#               SaleDate  SalePrice    LegalReference SoldAsVacant  \
# 8397  October 15, 2015   362500.0  20151019-0106061           No
#
#                        OwnerName                   OwnerAddress  ...  \
# 8397  WARD, SANDRA S. & DAVID S.  1219  N 2ND ST, NASHVILLE, TN  ...
#
#       BuildingValue TotalValue  YearBuilt  Bedrooms  FullBath  HalfBath  \
# 8397       290700.0   330600.0     2015.0       4.0       2.0       1.0
#
#       New Date        City  New SalePrice New SalePrice2
# 8397  20151019   NASHVILLE                      362,500
#
# [1 rows x 23 columns]

# %%
df.to_csv('new Nashville.csv', index=False)

# %%
df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress            SaleDate  SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013   240000.0
# 1  1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014   366000.0
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016   435000.0
# 3  1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016   255000.0
# 4  1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014   278000.0
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# ...

# %%
df['SalePrice'] = df['SalePrice'].astype('int')

# %%
df.dtypes
# Out:
# UniqueID             int64
# ParcelID            object
# LandUse             object
# PropertyAddress     object
# SaleDate            object
# SalePrice            int32
# LegalReference      object
# SoldAsVacant        object
# OwnerName           object
# OwnerAddress        object
# Acreage            float64
# TaxDistrict         object
# LandValue          float64
# BuildingValue      float64
# TotalValue         float64
# YearBuilt          float64
# Bedrooms           float64
# FullBath           float64
# HalfBath           float64
# New Date            object
# City                object
# New SalePrice       object
# New SalePrice2      object
# dtype: object

# %%
# Change data type of column 'int64'

df['SalePrice'] = df['SalePrice'].astype('int64')

# %%
df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress            SaleDate  SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013     240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014     366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016     435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016     255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014     278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# ...

# %%
# Add new Column for Year

df['Year'] = df['LegalReference'].astype(str).str[:4]

# %%
df
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress            SaleDate  SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013     240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014     366000
# ...

# %%
# Delete drop columns

df = df.drop(columns=['New SalePrice2'])

# %%
df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress            SaleDate  SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013     240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014     366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016     435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016     255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014     278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# ...

# %%
df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress            SaleDate SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014    366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016    435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016    255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014    278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE
# ...

# %%
df['BuildingValue'] = df['BuildingValue'].fillna(0)

df['TotalValue'] = df['TotalValue'].fillna(0)

# %%
df['TotalValue'] = df['TotalValue'].astype('int64')

# %%
df['BuildingValue'] = df['BuildingValue'].astype('int64')

# %%
# scatter plot with TotalValue vs Building Value

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10,8)

plt.scatter(x=df['BuildingValue'], y=df['TotalValue'])

plt.title('Total Value vs Building Value')
plt.xlabel('BuildingValue')
plt.ylabel('TotalValue')
plt.show()

# %%
#Sort by TotalValue

df.sort_values(by=['TotalValue'], inplace=False, ascending=False)
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 10489      20137   073 00 0 042.00                   CHURCH
# 38089      23769   132 06 0 036.00            SINGLE FAMILY
# 38088       9674   132 06 0 036.00            SINGLE FAMILY
# 36405       1099   130 03 0 122.00            SINGLE FAMILY
# 42319       1152   144 13 0 013.00          VACANT RES LAND
# ...          ...               ...                      ...
# 28137      55666  105 09 0W 005.00        RESIDENTIAL CONDO
# 28136      54141  105 09 0W 004.00        RESIDENTIAL CONDO
# 28135      54140  105 09 0W 003.00        RESIDENTIAL CONDO
# 28134      55665  105 09 0W 002.00        RESIDENTIAL CONDO
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                           PropertyAddress            SaleDate SalePrice  \
# 10489      2800  MCGAVOCK PIKE, NASHVILLE     August 15, 2014  12350000
# 38089      4225  FRANKLIN PIKE, NASHVILLE   November 17, 2014   1100000
# ...

# %%
sns.regplot(x='BuildingValue', y='TotalValue', data=df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='BuildingValue', ylabel='TotalValue'>

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[322], line 1
# ----> 1 df.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...
